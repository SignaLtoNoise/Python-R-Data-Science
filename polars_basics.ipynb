# %%
pip install polars
# Out:
# ...
#    ---------------------------------------- 0.0/828.7 kB ? eta -:--:--
#    ---------------------------------------- 828.7/828.7 kB 12.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/51.8 MB ? eta -:--:--
#    - -------------------------------------- 1.3/51.8 MB 10.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.6/51.8 MB 7.2 MB/s eta 0:00:07
#    -- ------------------------------------- 3.1/51.8 MB 5.3 MB/s eta 0:00:10
#    -- ------------------------------------- 3.1/51.8 MB 5.3 MB/s eta 0:00:10
#    -- ------------------------------------- 3.4/51.8 MB 3.2 MB/s eta 0:00:16
#    --- ------------------------------------ 4.7/51.8 MB 3.6 MB/s eta 0:00:13
#    --- ------------------------------------ 5.0/51.8 MB 3.5 MB/s eta 0:00:14
#    ---- ----------------------------------- 5.5/51.8 MB 3.2 MB/s eta 0:00:15
#    ---- ----------------------------------- 6.0/51.8 MB 3.2 MB/s eta 0:00:15
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------- ----------- 1.3/1.8 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 8.7 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.14.exe and pip3.exe are installed in 'C:\Users\Michael\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import polars as pl
